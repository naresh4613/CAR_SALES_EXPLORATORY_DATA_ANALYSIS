# %% [markdown]
# # CAR_SALES_EXPLORATORY DATA ANALYSIS

# %%
[Questions]
    - 1 [Which type of cars are sold maximum?]
    - 2 [What is the co-relation between price and mileage?]
    - 3 [How many cars are registered?]
    - 4 [Price distribution between registered and non-registered cars.]
    - 5 [What is the car price distribution based on Engine Value?]
    - 6 [Which Engine Type of cars users preferred maximum?]
    - 7 [Establish corelation between all features using heatmap.]
    - 8 [Distribution of Price]

# %% [markdown]
# Importing required libraries

# %%
import numpy as np
import pandas as pd
import pandas_profiling
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set()
from subprocess import check_output
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_19964\3874682350.py:3: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   import pandas_profiling

# %% [markdown]
# loading dataset

# %%
car_sales=pd.read_excel(r"C:\Users\ASUS\Downloads\Car_Sales.xlsx")

# %%
car_sales
# Out:
#                 car    price       body  mileage  engV engType registration  \
# 0              Ford  15500.0  crossover       68   2.5     Gas          yes
# 1     Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2     Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3     Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4     Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
# ...             ...      ...        ...      ...   ...     ...          ...
# 9571        Hyundai  14500.0  crossover      140   2.0     Gas          yes
# 9572     Volkswagen   2200.0      vagon      150   1.6  Petrol          yes
# 9573  Mercedes-Benz  18500.0  crossover      180   3.5  Petrol          yes
# 9574          Lexus  16999.0      sedan      150   3.5     Gas          yes
# 9575           Audi  22500.0      other       71   3.6  Petrol          yes
#
#       year      model  drive
# ...

# %%
car_sales.head(5)
# Out:
#              car    price       body  mileage  engV engType registration  \
# 0           Ford  15500.0  crossover       68   2.5     Gas          yes
# 1  Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2  Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3  Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4  Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
#
#    year    model  drive
# 0  2010     Kuga   full
# 1  2011  E-Class   rear
# 2  2008   CL 550   rear
# 3  2012    B 180  front
# 4  2013  E-Class    NaN

# %%
car_sales.tail(5)
# Out:
#                 car    price       body  mileage  engV engType registration  \
# 9571        Hyundai  14500.0  crossover      140   2.0     Gas          yes
# 9572     Volkswagen   2200.0      vagon      150   1.6  Petrol          yes
# 9573  Mercedes-Benz  18500.0  crossover      180   3.5  Petrol          yes
# 9574          Lexus  16999.0      sedan      150   3.5     Gas          yes
# 9575           Audi  22500.0      other       71   3.6  Petrol          yes
#
#       year      model  drive
# 9571  2011     Tucson  front
# 9572  1986  Passat B2  front
# 9573  2008     ML 350   full
# 9574  2008     ES 350  front
# 9575  2007         Q7   full

# %%
car_sales_copy=car_sales.copy()

# %%
car_sales_copy
# Out:
#                 car    price       body  mileage  engV engType registration  \
# 0              Ford  15500.0  crossover       68   2.5     Gas          yes
# 1     Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2     Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3     Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4     Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
# ...             ...      ...        ...      ...   ...     ...          ...
# 9571        Hyundai  14500.0  crossover      140   2.0     Gas          yes
# 9572     Volkswagen   2200.0      vagon      150   1.6  Petrol          yes
# 9573  Mercedes-Benz  18500.0  crossover      180   3.5  Petrol          yes
# 9574          Lexus  16999.0      sedan      150   3.5     Gas          yes
# 9575           Audi  22500.0      other       71   3.6  Petrol          yes
#
#       year      model  drive
# ...

# %% [markdown]
# # Data Profiling

# %%
car_sales.shape
# Out:
# (9576, 10)

# %%
car_sales.count()
# Out:
# car             9576
# price           9576
# body            9576
# mileage         9576
# engV            9142
# engType         9576
# registration    9576
# year            9576
# model           9576
# drive           9065
# dtype: int64

# %%
car_sales.describe(include="all")
# Out:
#                car          price   body      mileage         engV engType  \
# count         9576    9576.000000   9576  9576.000000  9142.000000    9576
# unique          87            NaN      6          NaN          NaN       4
# top     Volkswagen            NaN  sedan          NaN          NaN  Petrol
# freq           936            NaN   3646          NaN          NaN    4379
# mean           NaN   15633.317316    NaN   138.862364     2.646344     NaN
# std            NaN   24106.523436    NaN    98.629754     5.927699     NaN
# min            NaN       0.000000    NaN     0.000000     0.100000     NaN
# 25%            NaN    4999.000000    NaN    70.000000     1.600000     NaN
# 50%            NaN    9200.000000    NaN   128.000000     2.000000     NaN
# 75%            NaN   16700.000000    NaN   194.000000     2.500000     NaN
# max            NaN  547800.000000    NaN   999.000000    99.990000     NaN
#
#        registration         year    model  drive
# ...

# %%
car_sales.sort_values(by=["price"],ascending=False).head(10)
# Out:
#                 car     price       body  mileage  engV engType registration  \
# 7621        Bentley  547800.0      sedan        0  6.75  Petrol          yes
# 7914        Bentley  499999.0  crossover        0  6.00  Petrol          yes
# 1611        Bentley  499999.0  crossover        0  6.00  Petrol          yes
# 4134        Bentley  449999.0  crossover        0  6.00  Petrol          yes
# 4325  Mercedes-Benz  300000.0      sedan       68  6.00  Petrol          yes
# 5849  Mercedes-Benz  300000.0      other       37  5.00  Petrol          yes
# 1891  Mercedes-Benz  295000.0      sedan       29  6.00  Petrol          yes
# 2165  Mercedes-Benz  295000.0      sedan       29  6.00  Petrol          yes
# 8205     Land Rover  285000.0  crossover        0  5.00  Petrol          yes
# 1478        Bentley  259000.0      sedan        0  6.00  Petrol          yes
#
#       year        model drive
# 7621  2016     Mulsanne  rear
# 7914  2016     Bentayga  full
# ...

# %%
car_sales.groupby('car')['price'].count().sort_values(ascending=False)
# Out:
# car
# Volkswagen       936
# Mercedes-Benz    921
# BMW              694
# Toyota           541
# VAZ              489
#                 ...
# Fisker             1
# Samsung            1
# Maserati           1
# Saab               1
# Lamborghini        1
# Name: price, Length: 87, dtype: int64

# %% [markdown]
# It has been observed that top 3 selling car are : Volkswagen ,Mercedes-Benz, BMW

# %%
car_sales.corr()
# Out:
#             price   mileage      engV      year
# price    1.000000 -0.312415  0.051070  0.370379
# mileage -0.312415  1.000000  0.047070 -0.495599
# engV     0.051070  0.047070  1.000000 -0.042251
# year     0.370379 -0.495599 -0.042251  1.000000

# %%
import seaborn as sns
sns.set()
plt.subplots(figsize=(10,20))
sns.heatmap(car_sales.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=car_sales.engV)
# Out:
# <AxesSubplot:>

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9576 entries, 0 to 9575
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   car           9576 non-null   object
#  1   price         9576 non-null   float64
#  2   body          9576 non-null   object
#  3   mileage       9576 non-null   int64
#  4   engV          9142 non-null   float64
#  5   engType       9576 non-null   object
#  6   registration  9576 non-null   object
#  7   year          9576 non-null   int64
#  8   model         9576 non-null   object
#  9   drive         9065 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 748.2+ KB

# %%
car_sales.isnull().sum()
# Out:
# car               0
# price             0
# body              0
# mileage           0
# engV            434
# engType           0
# registration      0
# year              0
# model             0
# drive           511
# dtype: int64

# %% [markdown]
# from the above output we have observed that engv and drive column contains maximumm null values  , we will see how to deal with them

# %% [markdown]
# # pre profiling

# %%
pip install pandas_profiling ##installing pandas profilling packages
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Invalid requirement: '##installing'

# %%
profile=pandas_profiling.ProfileReport(car_sales)

# %%
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.6.6&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2023-03-03 03:00:37.835825&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
profile.to_file(output_file="car_sales_before_preprocessing.html")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # preprocessing

# %%
car_sales.duplicated().sum()
# Out:
# 113

# %%
car_sales.loc[car_sales.duplicated(), :]
# Out:
#                 car     price       body  mileage  engV engType registration  \
# 18           Nissan   16600.0  crossover       83   2.0  Petrol          yes
# 42    Mercedes-Benz   20400.0      sedan      190   1.8     Gas          yes
# 70    Mercedes-Benz       0.0  crossover        0   3.0  Diesel          yes
# 86           Toyota  103999.0  crossover        0   4.5  Diesel          yes
# 98    Mercedes-Benz   20400.0      sedan      190   1.8     Gas          yes
# ...             ...       ...        ...      ...   ...     ...          ...
# 9156     Volkswagen   15700.0      sedan      110   1.8  Petrol          yes
# 9163  Mercedes-Benz   20500.0      sedan      222   5.5  Petrol          yes
# 9164            VAZ    3900.0      hatch      121   1.4  Petrol          yes
# 9169        Hyundai   12900.0  crossover       49   2.7  Petrol          yes
# 9477            BMW   77777.0      sedan        8   4.4  Petrol          yes
#
#       year             model  drive
# ...

# %%
car_sales_copy.drop_duplicates(inplace=True)

# %%
car_sales_copy.loc[car_sales.duplicated(), :]
# Out:
# Empty DataFrame
# Columns: [car, price, body, mileage, engV, engType, registration, year, model, drive]
# Index: []

# %%
car_sales_copy
# Out:
#                 car    price       body  mileage  engV engType registration  \
# 0              Ford  15500.0  crossover       68   2.5     Gas          yes
# 1     Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2     Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3     Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4     Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
# ...             ...      ...        ...      ...   ...     ...          ...
# 9571        Hyundai  14500.0  crossover      140   2.0     Gas          yes
# 9572     Volkswagen   2200.0      vagon      150   1.6  Petrol          yes
# 9573  Mercedes-Benz  18500.0  crossover      180   3.5  Petrol          yes
# 9574          Lexus  16999.0      sedan      150   3.5     Gas          yes
# 9575           Audi  22500.0      other       71   3.6  Petrol          yes
#
#       year      model  drive
# ...

# %%
b=car_sales_copy["drive"].mode()

# %%
b
# Out:
# 0    front
# Name: drive, dtype: object

# %%
car_sales_copy["drive"]=car_sales_copy["drive"].fillna("front")

# %%
car_sales.isnull().sum()
# Out:
# car               0
# price             0
# body              0
# mileage           0
# engV            434
# engType           0
# registration      0
# year              0
# model             0
# drive           511
# dtype: int64

# %%
print(car_sales_copy.duplicated().sum())
# Out:
# 0

# %%
car_sales_copy.loc[car_sales.duplicated(keep=False), :]
# Out:
#                 car    price       body  mileage  engV engType registration  \
# 0              Ford  15500.0  crossover       68   2.5     Gas          yes
# 1     Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 3     Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 5            Nissan  16600.0  crossover       83   2.0  Petrol          yes
# 7           Renault  10500.0      vagon      185   1.5  Diesel          yes
# ...             ...      ...        ...      ...   ...     ...          ...
# 7536  Mercedes-Benz  20500.0      sedan      222   5.5  Petrol          yes
# 7691        Hyundai      0.0  crossover        0   2.2  Diesel          yes
# 7996           Opel  11700.0      hatch       30   1.6     Gas          yes
# 8160           Ford  16699.0      other      133   4.0  Petrol          yes
# 8829          Honda  40900.0  crossover        0   1.6  Diesel          yes
#
#       year     model  drive
# ...

# %%
car_sales.drop_duplicates(keep='first').shape
# Out:
# (9463, 10)

# %%
car_sales_copy['engV']=car_sales_copy.groupby(['car','body'])['engV'].transform(lambda x: x.fillna(x.median()))

# %%
car_sales_copy.isnull().sum()
# Out:
# car              0
# price            0
# body             0
# mileage          0
# engV            10
# engType          0
# registration     0
# year             0
# model            0
# drive            0
# dtype: int64

# %% [markdown]
# 422 missing value of engV has been replaced however , still 10 entries are left as missing,lets see the missing value data.

# %%
car_sales_copy[car_sales_copy.engV.isnull()]
# Out:
#           car     price       body  mileage  engV engType registration  year  \
# 319     Tesla   58000.0      hatch       52   NaN   Other          yes  2013
# 1437    Tesla  178500.0  crossover        0   NaN   Other          yes  2016
# 2486    Tesla  185000.0  crossover        1   NaN   Other          yes  2016
# 5084      GAZ       0.0  crossover        1   NaN  Petrol          yes  1963
# 6773      UAZ    3000.0      other        1   NaN   Other          yes  1985
# 8569    Tesla  176900.0  crossover        0   NaN   Other          yes  2016
# 8824   Fisker       0.0      other      100   NaN   Other          yes  2001
# 8905  Changan    6028.0  crossover      101   NaN   Other          yes  2005
# 9360   Barkas    5500.0        van       80   NaN  Petrol          yes  2015
# 9566      UAZ     850.0        van      255   NaN   Other          yes  1981
#
#         model  drive
# 319   Model S  front
# 1437  Model X   full
# 2486  Model X   full
# 5084       69   full
# ...

# %% [markdown]
# Replacing NaN  values of drive with most common values of drive from car and body group.

# %%
def f(x):
    if x.count()<=0:
        return np.nan
    return x.value_counts().index[0]

car_sales_copy['drive'] = car_sales_copy['drive'].fillna(car_sales_copy.groupby(['car','body'])['drive'].transform(f))
#CarSales_Data[CarSales_Data.drive.isnull()]

# %%
car_sales_copy[car_sales_copy.drive.isnull()]
# Out:
# Empty DataFrame
# Columns: [car, price, body, mileage, engV, engType, registration, year, model, drive]
# Index: []

# %%
car_sales_copy.isnull().sum()
# Out:
# car              0
# price            0
# body             0
# mileage          0
# engV            10
# engType          0
# registration     0
# year             0
# model            0
# drive            0
# dtype: int64

# %%
car_sales_copy.dropna(subset=['engV'],inplace=True)
car_sales_copy.dropna(subset=['drive'],inplace=True)
car_sales_copy.isnull().sum()
# Out:
# car             0
# price           0
# body            0
# mileage         0
# engV            0
# engType         0
# registration    0
# year            0
# model           0
# drive           0
# dtype: int64

# %% [markdown]
# Dropping entries with price <=0

# %%
carsales_copy = car_sales_copy.drop(car_sales_copy[car_sales_copy.price <= 0 ].index)

# %%
car_sales_copy.price[car_sales_copy.price ==0].count()
# Out:
# 238

# %%
b = car_sales_copy["mileage"].median()
car_sales_copy["mileage"]=car_sales_copy["mileage"].replace(0,b)

# %%
car_sales_copy[car_sales_copy.mileage == 0]
# Out:
# Empty DataFrame
# Columns: [car, price, body, mileage, engV, engType, registration, year, model, drive]
# Index: []

# %%
car_sales_copy
# Out:
#                 car    price       body  mileage  engV engType registration  \
# 0              Ford  15500.0  crossover       68   2.5     Gas          yes
# 1     Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2     Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3     Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4     Mercedes-Benz  33000.0      vagon       91   2.3   Other          yes
# ...             ...      ...        ...      ...   ...     ...          ...
# 9571        Hyundai  14500.0  crossover      140   2.0     Gas          yes
# 9572     Volkswagen   2200.0      vagon      150   1.6  Petrol          yes
# 9573  Mercedes-Benz  18500.0  crossover      180   3.5  Petrol          yes
# 9574          Lexus  16999.0      sedan      150   3.5     Gas          yes
# 9575           Audi  22500.0      other       71   3.6  Petrol          yes
#
#       year      model  drive
# ...

# %%
profile_cleaned = pandas_profiling.ProfileReport(car_sales_copy)
profile_cleaned.to_file(output_file="car_sales_post_preprocessing.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# The data are processed now. The dataset doesnot contain missing and zero values. The pandas profiling report generated after processing the data giving us more clear data. We can compare the two reports.

# %% [markdown]
# ### Which type of cars are sold maximum?

# %%
sns.countplot(x='body',data=car_sales_copy).set_title('count plot for car varient')
# Out:
# Text(0.5, 1.0, 'count plot for car varient')

# %% [markdown]
# we can see sedan cars are sold maximum and followed that crossover,hatch,van,other and vagon

# %% [markdown]
# ### What is the co-relation between price and mileage?

# %%
sns.regplot(x= 'mileage',y = 'price',data = car_sales_copy)
# Out:
# <AxesSubplot:xlabel='mileage', ylabel='price'>

# %% [markdown]
# You can see there are some outliers here. Excluding those,it seems that majority of car price is below 150000 and gives mileage in the range of 0 to 400.

# %% [markdown]
# ### How many cars are registered?

# %%
car_sales_copy["registration"].value_counts()
# Out:
# yes    8892
# no      561
# Name: registration, dtype: int64

# %%
sns.countplot('registration',data=car_sales_copy).set_title('Car Registration status')
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Car Registration status')

# %% [markdown]
# 8000+ cars are registered and very few are not registered

# %% [markdown]
# ### Price distribution between registered and non-registered cars.

# %%
car_sales_copy.groupby(['registration','body'])['price'].mean()
# Out:
# registration  body
# no            crossover     7816.542373
#               hatch         2563.750000
#               other         3817.393939
#               sedan         3906.605691
#               vagon         3055.507353
#               van           3488.457143
# yes           crossover    29400.477100
#               hatch         8606.659842
#               other        19714.860379
#               sedan        12613.659852
#               vagon         9944.810356
#               van          10531.747228
# Name: price, dtype: float64

# %%
sns.boxplot(x='registration',y='price',data = car_sales_copy)
# Out:
# <AxesSubplot:xlabel='registration', ylabel='price'>

# %% [markdown]
# Majority of the cars are registered and the price of those cars are below 300000. Non-registered cars are cheaper in cost.

# %%
sns.displot(car_sales_copy, x="registration", y='price')

# %%
plt = car_sales_copy[['price', 'registration']].groupby('registration').price.mean().plot(kind='bar')
plt
# Out:
# <AxesSubplot:xlabel='registration'>

# %% [markdown]
# ### What is the car price distribution based on Engine Value?

# %%
sns.regplot(x='engV',y='price',data = car_sales_copy)
# Out:
# <AxesSubplot:xlabel='engV', ylabel='price'>

# %% [markdown]
# Except few outliers, it is clearly observed that the range of car price is between 0 to 150000 having the range of engine value between 0 to 6.

# %%
sns.scatterplot(x='engV',y='price', data=car_sales_copy, hue='body')
# Out:
# <AxesSubplot:xlabel='engV', ylabel='price'>

# %%
sns.relplot(data=car_sales_copy,x='engV',y='price')

# %% [markdown]
# ### Which engine type of cars users preferred maximum?

# %% [markdown]
# Petrol cars are more preferred and followed by Diesel, Gas and others.

# %%
car_sales_copy.groupby('engType')['price'].count().sort_values(ascending=False)
# Out:
# engType
# Petrol    4339
# Diesel    2950
# Gas       1710
# Other      454
# Name: price, dtype: int64

# %%
sns.countplot(car_sales_copy['engType'])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='engType', ylabel='count'>

# %% [markdown]
# ### Establish coorelation between all the features using heatmap.

# %%
corr_car_sales = car_sales_copy.corr()
corr_car_sales
# Out:
#             price   mileage      engV      year
# price    1.000000 -0.246700  0.048471  0.375890
# mileage -0.246700  1.000000  0.052856 -0.452136
# engV     0.048471  0.052856  1.000000 -0.043109
# year     0.375890 -0.452136 -0.043109  1.000000

# %%
##plt.subplots(figsize=(10,10))
sns.heatmap(corr_car_sales,vmax = 0.8 , linewidth = 0.01 ,square = True,cmap = 'YlGnBu',linecolor = 'black')
plt.title('Correlation between features')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19964\2561644454.py in <module>
#       1 ##plt.subplots(figsize=(10,10))
#       2 sns.heatmap(corr_car_sales,vmax = 0.8 , linewidth = 0.01 ,square = True,cmap = 'YlGnBu',linecolor = 'black')
# ----> 3 plt.title('Correlation between features')
#
# TypeError: 'Text' object is not callable

# %% [markdown]
# mileage and engV are negatively corelated with year.
#
# mileage is also negatively corelated with year.
#
# engV is positively coorelated with mileage and price.
#
# Positive corelation observed between year and price too.

# %% [markdown]
# ###  Distribution of price.

# %%
sns.distplot(car_sales_copy['price'],color = 'g')
plt.title("Price Distribution")
plt.show()
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19964\3297751996.py in <module>
#       1 sns.distplot(car_sales_copy['price'],color = 'g')
# ----> 2 plt.title("Price Distribution")
#       3 plt.show()
#
# TypeError: 'Text' object is not callable

# %% [markdown]
# The __'price'__ mostly varies between _0 and 80000.

# %%
sns.distplot(car_sales_copy['price'], color='g', kde=False)
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price'>

# %% [markdown]
# Conclusion:
#
# Sedan cars sold maximum.
#
# Price is increasing as the engine value is increasing.
#
# The price and mileage goes down as engine values decreasing.

# %%
sns.histplot(data=car_sales_copy, x="price", hue="body")
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>
